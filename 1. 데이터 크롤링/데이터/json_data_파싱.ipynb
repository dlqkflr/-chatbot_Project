# %%
import json

with open('json_data/고민상담/고민상담_naver_to_1_all.json', 'rt', encoding='utf-8') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'lastBuildDate': 'Thu, 26 Sep 2019 16:27:49 +0900',
#  'total': 171382,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '<b>고민상담</b>을 하고싶어요',
#    'link': 'https://kin.naver.com/qna/detail.nhn?d1id=10&dirId=10010101&docId=335625048&qb=6rOg66+87IOB64u0&enc=utf8&section=kin.qna&rank=1&search_sort=0&spq=0',
#    'description': '<b>고민상담</b>을 하고싶어요 제가 요즘 생각이 너무 많아졌어요 학교에서 친구들... 많아져서 <b>고민 상담</b>이 필요하신가 봅니다. 주변 사람들이 모두 적인 것... 이로 인한 <b>고민 상담</b>을 받고자 하시는데 님의 고민 해결에 조금이라도... '},
#   {'title': '<b>고민상담</b> 25세입니다.',
#    'link': 'https://kin.naver.com/qna/detail.nhn?d1id=6&dirId=602060402&docId=327547938&qb=6rOg66+87IOB64u0&enc=utf8&section=kin.qna&rank=2&search_sort=0&spq=0',
#    'description': '... 2년전부터 우울증을 앓고있습니다. 정말죽고싶습니다.. <b>고민상담</b>도와주실분안계시나요..  안녕하세요. 서울지방변호사회-네이버 지식iN 상담변호사 김효준 입니다. 부모님 이야기하여 피해자들과 합의를 하시기 바랍니다'},
#   {'title': '고등학생 <b>고민상담</b>',
# ...

# %%
a =data['items'][3]['link']
a
# Out:
# 'https://kin.naver.com/qna/detail.nhn?d1id=11&dirId=1121&docId=336308785&qb=6rOg66+87IOB64u0&enc=utf8&section=kin.qna&rank=4&search_sort=0&spq=0'

# %%
import requests

# %%
re = requests
b = re.get(a)
c =b.text

# %%
from bs4 import BeautifulSoup
s = BeautifulSoup(c, 'lxml')

# %%
x= s.find('div',class_= 'c-heading')

# %%
x.text
# Out:
# '\n\n질문\n\n\n\n\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t진로고민 상담해주세요 ㅠ\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t안녕하세요 이번에 고등학교 졸업이 다가오는데 진로고민 때문에  너무 잠이 안와서요 대학갈 실력도 안되고  비용도 부담인데 학력 때문에 취업진로고민도 있고  원하는 방향의 진로가 없어서 더 고민인데  이런부분 생각하면 더 진로해 막막함을 느껴서ㅠ  고민해결 상담 좀 도와주세요 ㅠ\n\t\t\t\t\t\n'
